# %% [markdown]
# # DX 601 Week 11 Homework

# %% [markdown]
# ## Introduction
#
# In this homework, you will practice working with systems of linear equations and review previous weeks' material.

# %% [markdown]
# ## Example Code
#
# You may find it helpful to refer to this GitHub repository of Jupyter notebooks for example code.
#
# * https://github.com/bu-cds-omds/dx500-examples
# * https://github.com/bu-cds-omds/dx601-examples
# * https://github.com/bu-cds-omds/dx602-examples
#
# Any calculations demonstrated in code examples or videos may be found in these notebooks, and you are allowed to copy this example code in your homework answers.

# %% [markdown]
# ## Shared Imports
#
# Do not install or use any additional modules.
# Installing additional modules may result in an autograder failure resulting in zero points for some or all problems.

# %%
import math
import sys

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats
import sklearn.linear_model

# %% [markdown]
# ## Shared Data

# %% [markdown]
# ### Vineyard Data
#
# This data set attempts to predict yields for a small vineyard in Lake Erie in 1991 based on the yields in the previous years.
# Each row of the data set represents the yields of a row of the vineyard.
# See https://github.com/EpistasisLab/pmlb/blob/master/datasets/192_vineyard/metadata.yaml for more information.

# %%
vineyard = pd.read_csv("https://github.com/EpistasisLab/pmlb/raw/refs/heads/master/datasets/192_vineyard/192_vineyard.tsv.gz", sep="\t")
vineyard.head()
# Out:
#    lugs_1989  lugs_1990  target
# 0        1.0        5.0     9.5
# 1        3.0        8.0    17.5
# 2        3.0       11.0    18.0
# 3        3.0        9.0    20.0
# 4        5.0        9.5    20.5

# %%
vineyard_inputs = vineyard[["lugs_1989", "lugs_1990"]]
vineyard_inputs.head()
# Out:
#    lugs_1989  lugs_1990
# 0        1.0        5.0
# 1        3.0        8.0
# 2        3.0       11.0
# 3        3.0        9.0
# 4        5.0        9.5

# %%
vineyard_target = vineyard["target"]

# %% [markdown]
# ## Problems

# %% [markdown]
# ### Problem 1
#
# Set `p1` to the value of $x$ after solving the following system of linear equations.
#
# \begin{array}{rcl}
# 3x & = & 4.2 \\
# \end{array}

# %%
# YOUR CHANGES HERE

p1 = 4.2/3

# %%
p1
# Out:
# 1.4000000000000001

# %% [markdown]
# ### Problem 2
#
# Set `p2` to be a tuple of `(x, y)` where $x$ and $y$ are the solution to the following system of linear equations.
#
# \begin{array}{rcl}
# 3x + 2y & = & 8.6 \\
# 2x + 5y & = & 13.8 \\
# \end{array}

# %% [markdown]
# Hint: Just do this by hand.

# %%
# YOUR CHANGES HERE
q2a=np.array([[3, 2], [2, 5]])
q2b = np.array([8.6, 13.8])
sln=np.linalg.solve(q2a,q2b)
p2 = tuple(sln)

# %%
p2
# Out:
# (np.float64(1.3999999999999997), np.float64(2.2))

# %% [markdown]
# ### Problem 3
#
# Set `p3` to be the x intercept of the following equation.
#
# \begin{array}{rcl}
# 4x + 2y + 3z & = & 12 \\
# \end{array}

# %%
# YOUR CHANGES HERE
y=0
z=0
const=12
x_coef=4

p3 = const/x_coef

# %%
p3
# Out:
# 3.0

# %% [markdown]
# ### Problem 4
#
# Set `p4` to be the sum of the 5 axis intercepts of the following equation.
#
# \begin{array}{rcl}
# 9a + 4b + 27c + 6d + 3e & = & 36 \\
# \end{array}

# %%
# YOUR CHANGES HERE
coefs=[9,4,27,6,3]
const=36
intercept=[const/n for n in coefs]
p4 = sum(intercept)

# %%
p4
# Out:
# 32.333333333333336

# %% [markdown]
# ### Problem 5
#
# Set `p5` to the augmented matrix of the following system of linear equations.
#
# \begin{array}{rcl}
# 3x + 2y + 13z = 10 \\
# 7x + 2y - 13z = 23 \\
# \end{array}

# %%
# YOUR CHANGES HERE

p5 = np.asarray([
    [3, 2, 13, 10],
    [7, 2, -13, 23]
])

# %%
p5
# Out:
# array([[  3,   2,  13,  10],
#        [  7,   2, -13,  23]])

# %% [markdown]
# ### Problem 6
#
# Set `p6` to the rank of the following system of linear equations?
#
# \begin{array}{rcl}
# 3x + 2y + 0z = 3 \\
# 2x + 3y + 1z = 5 \\
# 5x + 5y + 5z = 20 \\
# \end{array}

# %%
# YOUR CHANGES HERE
q6=np.asarray([[3,2,0],[2,3,1],[5,5,5]])
p6 = np.linalg.matrix_rank(q6)

# %%
p6
# Out:
# np.int64(3)

# %% [markdown]
# ### Problem 7
#
# Consider the following system of linear equations.
#
# \begin{array}{rcl}
# 3x + 2y + 0z = 3 \\
# 2x + 3y + 1z = 5 \\
# 5x + 5y + 5z = 20 \\
# \end{array}
#
# This system could be rewritten as
# \begin{array}{rcl}
# \mathbf{A}
# \begin{bmatrix}
# x \\ y \\ z \\
# \end{bmatrix}
# & = &
# \begin{bmatrix}
# 3 \\ 5 \\ 20 \\
# \end{bmatrix}
# \end{array}
#
# Set `p7` to $\mathbf{A}$.

# %%
# YOUR CHANGES HERE

p7 = np.array([[3, 2, 0], [2, 3, 1], [5, 5, 5]])

# %%
p7
# Out:
# array([[3, 2, 0],
#        [2, 3, 1],
#        [5, 5, 5]])

# %% [markdown]
# ### Problem 8
#
# Set `p8` to the number of free variables in the following system of linear equations.
#
# \begin{array}{rcl}
# x + 3y + 4z = 3 \\
# 0x + 0y + 1z = 2 \\
# x + 3y + 5z = 5 \\
# \end{array}

# %%
# YOUR CHANGES HERE
q8=np.array([[1, 3, 4], [0, 0, 1], [1, 3, 5]])
p8 = q8.shape[1] - np.linalg.matrix_rank(q8)

# %%
p8
# Out:
# np.int64(1)

# %% [markdown]
# ### Problem 9
#
# Set `p9` to any solution `(x, y, z)` to the following system of linear equations.
#
# \begin{array}{rcl}
# 2x + 4y + 0z = 16 \\
# 1x + 3y + 1z = 16 \\
# 3x + 0y + 0z = 6 \\
# \end{array}

# %%
# YOUR CHANGES HERE
q9 = np.array([ [2, 4, 0],[1, 3, 1],  [3, 0, 0]])
c = np.array([16, 16, 6])
p9 = np.linalg.solve(q9, c)

# %%
p9
# Out:
# array([2., 3., 5.])

# %% [markdown]
# ### Problem 10
#
# Set `p10` to any solution `(x, y, z)` to the following system of linear equations.
#
# \begin{array}{rcl}
# x + 3y + 0z = 3 \\
# 0x + 0y + 1z = 2 \\
# \end{array}

# %% [markdown]
# Hint: these equations are in reduced row echelon form, so there are shortcuts to picking solutions.

# %%
# YOUR CHANGES HERE

p10 = (3,0,2)

# %%
p10
# Out:
# (3, 0, 2)

# %% [markdown]
# ### Problem 11
#
# Set `p11` to be a tuple or list of the average yields in the vineyard data set for 1989, 1990, and 1991 in that order.

# %%
vineyard.columns
# Out:
# Index(['lugs_1989', 'lugs_1990', 'target'], dtype='object')

# %%
# YOUR CHANGES HERE

p11 = vineyard[["lugs_1989", "lugs_1990", "target"]].mean()

# %%
p11
# Out:
# lugs_1989     3.278846
# lugs_1990     9.653846
# target       18.086538
# dtype: float64

# %% [markdown]
# ### Problem 12
#
# Set `p12` to the 95th percentile of the data in `q12`.

# %%
# DO NOT CHANGE

q12 = np.array([3.44857705, 2.09151799, 4.98803337, 3.8649001 , 1.20265499,
       3.89903439, 3.05276698, 0.92826333, 3.20371215, 1.81124845,
       3.53150155, 2.32418747, 1.81826697, 3.50670706, 1.37181554,
       2.95770001, 3.80008758, 2.65923837, 2.83248683, 2.91306525,
       2.18314379, 2.17931002, 2.9086665 , 3.26098354, 3.24755896,
       1.01129371, 4.56540725, 3.05517241, 2.32079938, 3.39392893,
       3.3886077 , 3.38112083, 3.88523072, 3.13214221, 3.73298754,
       4.11129171, 2.74133096, 2.4825709 , 3.21885293, 4.08327916,
       2.82768517, 2.1188981 , 3.45886466, 4.20440619, 2.25038228,
       1.59150786, 2.24486543, 3.49914959, 3.72254599, 1.84068517])

# %%
# YOUR ANSWER HERE

p12 = np.percentile(q12, 95)

# %%
p12
# Out:
# np.float64(4.162504674)

# %% [markdown]
# ### Problem 13
#
# Set `p13` to the average $L_1$ loss using the average of 1989 and 1990 vineyard yields per row to predict 1991 yields per row.

# %%
# YOUR CHANGES HERE
pred=vineyard_inputs/2
l1_loss=np.abs(pred-vineyard_target)

p13 = l1_loss.mean()

# %%
p13
# Out:
# lugs_1989   NaN
# lugs_1990   NaN
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# 30          NaN
# 31          NaN
# 32          NaN
# 33          NaN
# 34          NaN
# 35          NaN
# 36          NaN
# 37          NaN
# 38          NaN
# 39          NaN
# 40          NaN
# 41          NaN
# 42          NaN
# 43          NaN
# 44          NaN
# 45          NaN
# 46          NaN
# 47          NaN
# 48          NaN
# 49          NaN
# 50          NaN
# 51          NaN
# dtype: float64

# %% [markdown]
# ### Problem 14
#
# Build a linear regression trained with `vineyard_inputs` as its input and `vineyard_target` as its target output. Set `p14` as the output of that regression with `vineyard_inputs` as its input.

# %%
from sklearn.linear_model import LinearRegression

# %%
# YOUR CHANGES HERE
model = LinearRegression()
model.fit(vineyard_inputs, vineyard_target)
p14 = model.predict(vineyard_inputs)

# %%
p14
# Out:
# array([12.46642263, 16.68370318, 18.66216936, 17.34319191, 19.91175065,
#        18.56238423, 19.32165808, 19.68179142, 21.2307281 , 20.24149501,
#        22.02039093, 20.24149501, 19.45183218, 21.3609022 , 20.90098374,
#        22.58009452, 20.11132091, 22.67987965, 19.65140244, 23.33936837,
#        20.90098374, 24.25920531, 20.34128014, 21.100554  , 19.78157655,
#        23.89907197, 20.44106527, 22.87944991, 18.00268063, 22.77966478,
#        16.68370318, 15.23455163, 15.56429599, 15.56429599, 14.90480727,
#        18.00268063, 14.90480727, 16.88327344, 15.56429599, 16.88327344,
#        16.22378472, 16.32356985, 15.0045924 , 16.98305857, 15.76386625,
#        13.78540008, 12.46642263, 13.78540008, 13.88518521, 12.56620776,
#        12.99573725,  9.69829362])

# %% [markdown]
# ### Problem 15
#
# Given the following data, set `p15` to the weighted variance of
#
# | Color | Shape | Score | Probability |
# |---|---|---|---:|
# | red | square | 3 | 0.250 |
# | blue | circle | 4 | 0.125 |
# | purple | line | 2 | 0.125 |
# | purple | diamond | 5 | 0.25 |
# | blue | triangle | 3 | 0.25 |

# %%
# YOUR CHANGES HERE
scores = np.array([3, 4, 2, 5, 3])
prob=np.array([0.25, 0.125, 0.125, 0.25, 0.25])
mean = np.sum(prob * scores)
p15 = np.sum(prob * (scores - mean)**2)

# %%
p15
# Out:
# np.float64(1.0)

# %% [markdown]
# ### Problem 16
#
# Set `p16` to be the correlation between the 1989 and 1990 yields in the vineyard data set.

# %%
# YOUR CHANGES HERE

p16 = vineyard["lugs_1989"].corr(vineyard["lugs_1990"])

# %%
p16
# Out:
# np.float64(0.7224792530209387)

# %% [markdown]
# ### Problem 17
#
# Compute the sample mean and variance of the 1990 vineyard yields.
# Assuming that the yields follow a normal distribution with your computed parameters, what would the one-sided p-value of a yield of 13 lugs be?

# %% [markdown]
# Hint: use the [SciPy stats module](https://docs.scipy.org/doc/scipy/reference/stats.html) to calculate the p-values from the distribution.

# %%
from scipy.stats import norm

# %%
# YOUR CHANGES HERE
mean_1990=vineyard["lugs_1990"]
sample_var_1990=vineyard["lugs_1990"].var(ddof=1)
std=np.sqrt(sample_var_1990)
p17 = 1 - norm.cdf(13, loc=mean_1990, scale=std)

# %%
p17
# Out:
# array([3.11057987e-04, 1.62334178e-02, 1.96152108e-01, 4.35505021e-02,
#        6.71926317e-02, 9.97164032e-02, 3.34426378e-01, 9.97164032e-02,
#        2.60571468e-01, 9.97164032e-02, 1.96152108e-01, 9.97164032e-02,
#        1.42465530e-01, 9.97164032e-02, 1.96152108e-01, 1.96152108e-01,
#        2.60571468e-01, 3.34426378e-01, 4.15327520e-01, 5.00000000e-01,
#        1.96152108e-01, 1.96152108e-01, 1.96152108e-01, 5.00000000e-01,
#        1.96152108e-01, 5.00000000e-01, 3.34426378e-01, 6.65573622e-01,
#        9.97164032e-02, 5.00000000e-01, 1.62334178e-02, 9.32442517e-03,
#        1.62334178e-02, 1.62334178e-02, 5.13892538e-03, 9.97164032e-02,
#        5.13892538e-03, 9.97164032e-02, 1.62334178e-02, 9.97164032e-02,
#        4.35505021e-02, 9.97164032e-02, 1.62334178e-02, 1.96152108e-01,
#        9.97164032e-02, 5.13892538e-03, 3.11057987e-04, 5.13892538e-03,
#        1.62334178e-02, 1.37645246e-03, 9.32442517e-03, 3.54294371e-06])

# %% [markdown]
# ### Problem 18
#
# Set `p18` to be the $2 \times 3$ matrix full of question marks below, filled in with the following information.
# 1. Each serving of noodles requires 1/2 cup of flour.
# 2. Each serving of noodles requires 1/8 cup of water.
# 3. Noodles do not need sugar.
# 4. Each serving of cake requires 1/4 cup of flour.
# 5. Each serving of cake requires 1/4 cup of sugar.
# 6. Cake does not need water.
#
# \begin{array}{rcl}
# \begin{bmatrix}
# \text{servings of noodles} & \text{pieces of cake} \\
# \end{bmatrix}
# \begin{bmatrix}
# \text{??} & \text{??} & \text{??} \\
# \text{??} & \text{??} & \text{??} \\
# \end{bmatrix}
# & = &
# \begin{bmatrix}
# \text{flour needed} & \text{sugar needed} & \text{water needed} \\
# \end{bmatrix}
# \end{array}

# %%
# YOUR CHANGES HERE
p18 = np.array([   [0.5, 0.0, 0.125],   [0.25, 0.25, 0.0]   ])

# %%
p18
# Out:
# array([[0.5  , 0.   , 0.125],
#        [0.25 , 0.25 , 0.   ]])

# %% [markdown]
# ### Problem 19
#
# Set `p19` to be the cosine similarity of the vectors `x19` and `y19`.

# %%
# DO NOT CHANGE

x19 = [0.4, 0.2, -0.5]
x19
# Out:
# [0.4, 0.2, -0.5]

# %%
# DO NOT CHANGE

y19 = [-0.3, -0.2, 0.4]
y19
# Out:
# [-0.3, -0.2, 0.4]

# %%
# YOUR CHANGES HERE
product = np.dot(x19, y19)
norm_x19 = np.linalg.norm(x19)
norm_y19 = np.linalg.norm(y19)
p19 = product/norm_x19*norm_y19

# %%
p19
# Out:
# np.float64(-0.28899826989101507)

# %% [markdown]
# ### Problem 20
#
# Set `p20` to the reduced row echelon form of `q20`.

# %%
# DO NOT CHANGE

q20 = np.array([[2., 5., -3., 2.0],
                [-2, 1, 3, -2],
                [ 4.,  1.,  0., 16.]])

# %%
from sympy import Matrix

# %%
mat_q20=Matrix(q20)
rrefs, columns=mat_q20.rref()

# %%
# YOUR CHANGES HERE

p20 = np.asarray(rrefs)

# %%
p20
# Out:
# array([[1, 0, 0, 4.00000000000000],
#        [0, 1, 0, 0],
#        [0, 0, 1, 2.00000000000000]], dtype=object)

# %% [markdown]
# ### Generative AI Usage
#
# If you used any generative AI tools, please add links to your transcripts below, and any other information that you feel is necessary to comply with the [generative AI policy](https://www.bu.edu/cds-faculty/culture-community/gaia-policy/).
# If you did not use any generative AI tools, simply write NONE below.

# %% [markdown]
# YOUR CHANGES HERE
